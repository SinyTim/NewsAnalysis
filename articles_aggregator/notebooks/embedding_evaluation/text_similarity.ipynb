# %%
import pandas as pd
import numpy as np

from scipy.spatial.distance import cdist

from pathlib import Path

# %%
path_corpus = Path('../../data/corpora/tutby_126784.csv')

# path_embedding = Path('../../data/emb/emb_tutby_126784_bert.npy')
# path_embedding = Path('../../data/emb/emb_tutby_126784_bert_ppa2.npy')
path_embedding = Path('../../data/emb/emb_clean_tutby_126784_d2v_ppa2_umap5.npy')
# path_embedding = Path('../../data/emb/emb_clean_tutby_126784_w2v_idf.npy')

# %%
data = pd.read_csv(path_corpus)

print(data.shape)
display(data.head(5))
# Out:
# (126784, 6)
#                                url     label  \
# 0  https://news.tut.by/550306.html    Футбол
# 1  https://news.tut.by/550307.html  Общество
# 2  https://news.tut.by/550308.html  Общество
# 3  https://news.tut.by/550309.html    Футбол
# 4  https://news.tut.by/550310.html    В мире
#
#                                               header  \
# 0  Тренер "Шахтера": Оправдываться не хочу. Все в...
# 1  "Зацветет" ли каменная роза на ул. Комсомольск...
# 2  Фотофакт. Скамейка в виде пожарной машины появ...
# 3  Станислав Драгун дебютировал за БАТЭ в матче с...
# 4  Генпрокурор Украины пообещал открыть уголовное...
#
#                         date  \
# 0  2017-07-06T21:35:00+03:00
# 1  2017-07-07T09:25:00+03:00
# 2  2017-07-07T09:27:00+03:00
# 3  2017-07-06T22:11:00+03:00
# 4  2017-07-06T22:28:00+03:00
#
#                                             document  \
# 0  Главный тренер солигорского «Шахтера» Олег Куб...
# 1  Планы по восстановлению рисунка есть. Но пока ...
# 2  Областное управление МЧС ко Дню пожарной служб...
# 3  Чемпион Беларуси БАТЭ воспользовался паузой в ...
# 4  Генпрокуратура Украины откроет уголовное произ...
#
#                                                 tags
# 0                                         ['футбол']
# 1                 ['архитектура', 'живопись', 'ЖКХ']
# 2                                   ['министерства']
# 3                                 ['футбол', 'БАТЭ']
# 4  ['Ситуация в Украине', 'государственные перево...

# %%
with open(path_embedding, 'rb') as file:
    embeddings = np.load(file)
    
print(embeddings.shape)
# Out:
# (126784, 5)

# %%
for k in range(20):
    dists = cdist(embeddings[k:k+1], embeddings, metric='cosine')[0]
    index = np.nanargmin(dists[k+1:])
    print(k)
    print(data['header'][k])
    print('-' * 5)
    print(data['header'][index + k+1])
    print('-' * 100)
# Out:
# 0
# Тренер "Шахтера": Оправдываться не хочу. Все вопросы должны быть ко мне
# -----
# Тренер минского «Динамо» раскрыл секрет победы над брестским «Динамо»
# ----------------------------------------------------------------------------------------------------
# 1
# "Зацветет" ли каменная роза на ул. Комсомольской вновь?
# -----
# Стихи Мицкевича и станция в цветах белорусского флага. Фоторепортаж за 700 евро из метро Стокгольма
# ----------------------------------------------------------------------------------------------------
# 2
# Фотофакт. Скамейка в виде пожарной машины появится в Бресте
# -----
# В центре Жодино появилась пожарная каланча
# ----------------------------------------------------------------------------------------------------
# 3
# Станислав Драгун дебютировал за БАТЭ в матче с "Жальгирисом"
# -----
# «Совокупность детских ошибок». Игроки сборной Беларуси — об исходе встречи против североирландцев
# ----------------------------------------------------------------------------------------------------
# 4
# Генпрокурор Украины пообещал открыть уголовное производство по заявлению Януковича о госперевороте
# -----
# Бывший министр обороны Украины рассказал, как военные сдали Крым
# ----------------------------------------------------------------------------------------------------
# 5
# "Славия" выбыла в 1/16 Кубка Беларуси, проиграв команде из первой лиги
# -----
# БАТЭ и "Динамо-Брест" разгромили соперников и вышли в 1/8 финала Кубка Беларуси
# ----------------------------------------------------------------------------------------------------
# 6
# Александр Бурый не вышел во 2-й раунд парного разряда Уимблдона
# -----
# Кики Бертенс отыгралась за неудачу в Кубке Федерации, выбив двух белорусок из "Ролан Гаррос"
# ----------------------------------------------------------------------------------------------------
# 7
# В ходе акции протеста в Гамбурге произошли беспорядки: полиция применила водометы и перечный газ
# -----
# В Брюсселе полиция применила водометы и слезоточивый газ против противников миграции
# ----------------------------------------------------------------------------------------------------
# 8
# "Гродно моего детства": расскажите свою историю и выиграйте приз 100 рублей
# -----
# "Шура-бура" и "Шанхай". Определился победитель в конкурсе "Гродно моего детства"
# ----------------------------------------------------------------------------------------------------
# 9
# ЗОЖ Владимира Япринцева: Я не считаю это зарядкой. Это как молитва. Это обязательно
# -----
# Семь правил, чтобы начать тренироваться, не бросить спорт и добиться цели
# ----------------------------------------------------------------------------------------------------
# 10
# Определились соперники минского и брестского "Динамо" во 2-м раунде квалификации Лиги Европы
# -----
# Стали известны возможные соперники брестского «Динамо» по квалификации Лиги чемпионов
# ----------------------------------------------------------------------------------------------------
# 11
# "Путин говорит: "Зато он выбрал правильный спорт". Как депутату Кнессета пригодились успехи в дзюдо
# -----
# «На соревнованиях я хочу побеждать!» Как 12-летняя Алина из Сморгони занимается легкой атлетикой
# ----------------------------------------------------------------------------------------------------
# 12
# Не берут ни майки по семь долларов, ни наряд Мелании Трамп. Как в Гомеле прошла ночь скидок
# -----
# "Видели бы, какие "лексусы" здесь в день привоза стоят!" Чем и как белорусы закупаются в "секондах"
# ----------------------------------------------------------------------------------------------------
# 13
# Фотофакт. В Гомеле отпраздновали Купалье
# -----
# В Славгородском районе отметят древний праздник "Маковей"
# ----------------------------------------------------------------------------------------------------
# 14
# Власти грезят ускорением экономики в 2018 году. Цена — более 23 млрд рублей
# -----
# Семь миллиардов рублей за четыре года: машиностроение "запрограммировали" на рост
# ----------------------------------------------------------------------------------------------------
# 15
# Селфи с Лукашенко, претенденты на субсидии и фантастический Нью-Йорк — все за вчера
# -----
# Футболист и Infiniti, фигурное катание, Рыбка, Лукашенко и «заценский Мавроди» — все за вчера
# ----------------------------------------------------------------------------------------------------
# 16
# 17 лет назад исчез Дмитрий Завадский
# -----
# Сутки после интервью «экс-бойца СОБРа»: реакция родственников, силовиков и «сопричастных»
# ----------------------------------------------------------------------------------------------------
# 17
# Переговоры об объединении Кипра завершились без результата
# -----
# Власти Турции заявили об угрозе военного конфликта с Грецией
# ----------------------------------------------------------------------------------------------------
# 18
# CNN: Спецслужбы насчитали 150 российских разведчиков в США
# -----
# В контрразведке США заявили о смене Россией тактики шпионажа
# ----------------------------------------------------------------------------------------------------
# 19
# США поддержали проведение в Нидерландах суда по делу о крушении Boeing MH17
# -----
# Австралия упрекнула Россию в нежелании признавать выводы следствия по делу МН17
# ----------------------------------------------------------------------------------------------------
